# %%
import matplotlib.pyplot as plt
import torch
from models import res18_modd
import cv2

# %%
net = res18_modd()
net.load_state_dict(torch.load('saved_models/save_model.pt'))
net.eval();

# %%
img=plt.imread('data/test/Charlize_Theron_51.jpg')
# img=plt.imread('../IMG_20220814_132450-ImResizer (1).jpg')

# %%
plt.imshow(img)

# %%
res_gray=cv2.resize(cv2.cvtColor(img, cv2.COLOR_RGB2GRAY),(224,224))

# %%
plt.imshow(res_gray,cmap='gray')

# %%
o=net(torch.from_numpy(res_gray).unsqueeze(0).unsqueeze(0).float()/255)
o=o.detach().view(-1,2)*50+100
plt.imshow(res_gray,'gray')
plt.scatter(o[:,0],o[:,1],marker='+')
